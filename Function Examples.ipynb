# %% [markdown]
# ####Temperature Conversion

# %%
def tempconv(temp,unit):
  if unit=='C':
    return temp*9/5+32
  elif unit=='F':
    return (temp-32)*5/9

print(tempconv(25,'C'))
print(tempconv(77,'F'))
# Out:
# 77.0
# 25.0

# %% [markdown]
# ####Password Strength Checker

# %%
def check_pwd_Strength(password):
  if len(password)<8:
    return False
  if not any(char.islower() for char in password):
    return False
  if not any(char.isupper() for char in password):
    return False
  if not any(char.isdigit() for char in password):
    return False
  if not any(char for char in '!@#$%^&*()'):
    return False
  return True

print(f"{check_pwd_Strength('Str0ngPws!!')}")
print(f"{check_pwd_Strength('weakPassword')}")
# Out:
# True
# False

# %% [markdown]
# ####Calculate Total Cost of Items in Shopping Cart.

# %%
def costofcart(cart):
  total_cost=0
  for item in cart:
      total_cost += item['Quantity'] * item['Price']
  return total_cost

cart=[
    {'item 1' : 'Apple', 'Quantity' : 4 , 'Price' :10},
    {'item 2' : 'Orange', 'Quantity' : 2 , 'Price' : 5},
    {'item 3' : 'Kiwi', 'Quantity' : 6 , 'Price' : 5}
]

print(f"{costofcart(cart)}")
# Out:
# 80

# %% [markdown]
# ####Check if a String is a Palindrome

# %%
def CheckPal(string):
  string=string.lower().replace(" ","")
  return string==string[::-1]

string1="a man a plan a canal panama"
string2='radar'
string3='password'

print(f" Is {string1} a Palindrome : {CheckPal(string1)}")
print(f" Is {string2} a Palindrome : {CheckPal(string2)}")
print(f" Is {string3} a Palindrome : {CheckPal(string3)}")
# Out:
#  Is a man a plan a canal panama a Palindrome : True
#  Is radar a Palindrome : True
#  Is password a Palindrome : False

# %% [markdown]
# ####Calculate Factorials Of a Number using Recursion

# %%
def fact(num):
  if num==0 :
    return 1
  else:
    return num*fact(num-1)

number = 8
print(f"Factorial of {number} is {fact(number)} ")
# Out:
# Factorial of 8 is 40320

# %% [markdown]
# ####Function to Read a File and count Frequency of each Word.

# %%
import string

def wordfreq(filepath):
  word_count = {}
  with open (filepath,'r') as file:
    for line in file:
      line = line.lower()
      line = line.translate(str.maketrans('', '', string.punctuation))
      words = line.split()
      for word in words:
        word_count[word] = word_count.get(word,0) + 1
  return word_count


filename=('/content/Sample Text.txt')
Frequency=wordfreq(filename)
print(Frequency)
# Out:
# {'a': 4, 'man': 1, 'plan': 1, 'canal': 1, 'panama': 1, 'i': 1, 'am': 1, 'weakish': 1, 'speller': 1}
